# %%
print('Enter the length of sides of traingle:')
a = int(input('value of a='))
b = int(input('value of b='))
c = int(input('value of c='))
if a==b==c:
    print('It is equilateral triangle')
elif a==b or b==c or c==a:
    print('It is isoscelus traingle')
else:
    print('It is scalene triangle')
# Out:
# Enter the length of sides of traingle:
# value of a=6
# value of b=6
# value of c=5
# It is isoscelus traingle
